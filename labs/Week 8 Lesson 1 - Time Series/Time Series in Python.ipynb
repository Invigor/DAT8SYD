# %%
# !pip install pystan
# Out:
# Collecting pystan
#   Downloading pystan-2.16.0.0-cp36-cp36m-win_amd64.whl (32.5MB)
# Requirement already satisfied: numpy>=1.7 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from pystan)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from pystan)
# Installing collected packages: pystan
# Successfully installed pystan-2.16.0.0

# %%
# !pip install fbprophet
# Out:
# Collecting fbprophet
#   Downloading fbprophet-0.1.1.tar.gz
# Requirement already satisfied: matplotlib in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from fbprophet)
# Requirement already satisfied: numpy in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from fbprophet)
# Requirement already satisfied: pandas>=0.18.1 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from fbprophet)
# Requirement already satisfied: pystan>=2.14 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from fbprophet)
# Requirement already satisfied: six>=1.10 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: python-dateutil in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pytz in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: cycler>=0.10 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in c:\users\michael.stone\appdata\local\continuum\anaconda3\lib\site-packages (from pystan>=2.14->fbprophet)
# Building wheels for collected packages: fbprophet
#   Running setup.py bdist_wheel for fbprophet: started
#   Running setup.py bdist_wheel for fbprophet: still running...
#   Running setup.py bdist_wheel for fbprophet: finished with status 'done'
#   Stored in directory: C:\Users\michael.stone\AppData\Local\pip\Cache\wheels\43\f2\6c\5ed49d64b0aab1affc668d4555481db950fc4cc51658198951
# Successfully built fbprophet
# Installing collected packages: fbprophet
# Successfully installed fbprophet-0.1.1

# %%
# Import libraries
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
# Read in data
df = pd.read_csv('../../data/example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# Fit a time series model
m = Prophet()
m.fit(df);

# %%
# Predict future time series
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# Attach predicted values - yhat
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.199561    7.413950    8.903525
# 3266 2017-01-16  8.524560    7.774979    9.285715
# 3267 2017-01-17  8.311920    7.557278    9.044387
# 3268 2017-01-18  8.144517    7.405913    8.853210
# 3269 2017-01-19  8.156377    7.403470    8.851859

# %%
# Plot the forecasted values
from matplotlib import pyplot as plt
# %matplotlib inline

m.plot(forecast);

# %%
# Time Series Decomposition
m.plot_components(forecast);
